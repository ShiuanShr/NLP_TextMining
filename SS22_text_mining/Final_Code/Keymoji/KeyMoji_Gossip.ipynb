# %%
#text = "染疫輕症明明就該投輝瑞藥，結果現在都是叫輕症病人回家睡覺自己吃感冒藥，不知道為什麼輝瑞開藥領藥流程這麼麻煩，數量也根本不夠，導致普通人都領不到 還一直洗處方洗副作用，輕症變中重症然後就掛了 算誰的鍋？自己活該為什麼要染疫嗎？"
text = "桌球國手「小林同學」林昀儒驚傳返國採檢陽性反應確診。根據民視新聞報導，林昀儒剛結束在卡達的WTT球星挑戰賽，1日晚間搭機經泰國轉機返回台灣，抵達桃園機場進行落地採檢驗出「陽性」反應。對此消息林昀儒媽媽沒有否認，僅回應還在等待消息，謝謝大家關心。桌球國手「小林同學」林昀儒與國手鄭怡靜組成黃金混雙，31日在WTT球星挑戰賽決賽，再度對決法國組合黎貝森(Emmanuel Lebesson)／袁嘉楠，最終林昀儒／鄭怡靜可惜遭到對手直落三，收穫亞軍。"
# text = "戴資穎搭經濟艙賴清德道歉代表國家"

# %%
import csv
import pandas as pd
from string import punctuation
from wordcloud import STOPWORDS
import numpy as np 
import matplotlib.pyplot as plt
import re

# %%
#Mount google drive to google colab virtual machine
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ## 自建停用字
# my_stop_words = ['：','。','。','、','※','【','】',',','，','，','※','※', '」']
# term_stopwords = ['什麼','可以','我們','挑選','篇文章', '備註', '是', '新聞網','或', '的', '某' ,'啦', '分', '等', '才能','可以','我們','挑選','篇文章','你',
#         '知道','任何','如果','而且','不會','。',
#         '從來','外有','不論','記量','從來','只是','還是','这是','以便',
#         '放在','問個','同時','需登','有些','不用','一定','什麼',''
#         ,'運動給'
#         ,'結果'
#         ,'行為'
#         ,'另一台'
#         ,'这次','你','我','他','上次','']
# title_stopwords = ['新聞']
# special_sign = ['◆','▆','▍','▋','▲','◤','▼','▲','▲','◣','▎','◢', '～', '○', '●', '▼', '▲', '->', ':',
#                 '.','~~','!','?', '.', '/', '\ ']
# full_stopwords = list(STOPWORDS) + term_stopwords + special_sign + my_stop_words
# punctuation_str = punctuation
# punctuation_str
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def token_pack(text):
  ws_results = ws([text])
  pos_results = pos(ws_results)
  ner_results = ner(ws_results, pos_results)
  # print('\nws result: \n')
  # print(ws_results)
  # print('\nPOS result: \n')
  # print(pos_results)
  # for name in ner_results[0]:
  #   print(name)
  # 這邊我們直接丟掉NER與POS的結果
  text = ws_results
  return text 

def data_cleaning(str_list):
  string_content = str_list
  article_1 = [article.replace('\n', '') for article in string_content]
  tokens_list = [ token_pack(article) for article in article_1]
  clean_sentences = []
  for article in tokens_list:
    clean_tokens = []
    for _ in article:
      for token in _:
        # 去除token所有半形空白
        token = token.replace(' ', '')
        # 前後去除空白 #去除中英夾雜 #去除純數字
        if token.strip() != "" and not token.encode().isalpha()  and token.isdigit() == False:
          # 去除自建停用字
          if not token in full_stopwords:
            # 去除英文半形標點符號  #去除中文之標點符號
            if  not token in punctuation and not token in punctuation_str:
              clean_tokens.append(token)
      if len(clean_tokens)>0:
        clean_sentences.append(clean_tokens)
  return clean_sentences

# %%
def clean(string_content):
  article_1 = [article.replace('\n', '') for article in string_content]
#  [、_ =\ \\ [\ ] ; ' ，. / ~ ! @ # $ % ^ & *  + | ? > < 「 :{}]

  final_list = [re.sub('[^\u4E00-\u9FA50-9Re + ]', '', i) for i in article_1] # ，! @ # ? & ? > < 「」」「 {}
  final_list = [re.sub(' ', '', i) for i in final_list]

  return final_list

# %%
# PATH
import_pwd = '/content/drive/Shareddrives/Text Mining/CSV/Crawler/Gossip/'
save_path_title = "/content/drive/Shareddrives/Text Mining/CSV/temp_Title_Joanne/"
save_path_Keymoji = "/content/drive/Shareddrives/Text Mining/CSV/temp_keymoji_J/"

# %%
def store_to_csv(data, path):
  with open(path, 'w', newline='') as csvfile:
      writer = csv.writer(csvfile)
      writer.writerow(data)

# %%
def store_to_csv_df(data, path):
  with open(path, 'w', encoding = 'utf-8-sig') as f:
    data.to_csv(f)

# %%
# Gossip
name = "title_Gossip.csv"
Gossip = pd.read_csv(import_pwd +'Gossip_title_output.csv')
Gossip_title = clean(Gossip.columns)

path = save_path_title + name
# store_to_csv(Gossip_title, path)

# %%
# LEE
name = "title_LEE.csv"
LEE = pd.read_csv(import_pwd +'LEE_title_output.csv')
LEE_title = clean(LEE.columns)

path = save_path_title + name
# store_to_csv(LEE_title, path)

# %%
# GUO
name = "title_GUO.csv"
GUO = pd.read_csv(import_pwd +'GUO_title_output.csv')
GUO_title = clean(GUO.columns)

path = save_path_title + name
# store_to_csv(GUO_title, path)

# %%
# YANG
name = "title_YANG.csv"
YANG = pd.read_csv(import_pwd +'YANG_title_output.csv')
YANG_title = clean(YANG.columns)

path = save_path_title + name
# store_to_csv(YANG_title, path)

# %%
# TAI
name = "title_TAI.csv"
TAI = pd.read_csv(import_pwd +'TAI_title_output.csv')
TAI_title = clean(TAI.columns)

path = save_path_title + name
# store_to_csv(TAI_title, path)

# %%
# LIN
name = "title_LIN.csv"
LIN = pd.read_csv(import_pwd +'LIN_title_output.csv')
LIN_title = clean(LIN.columns)

path = save_path_title + name
# store_to_csv(LIN_title, path)

# %%
# store to dataframe
LEE_title_df = pd.DataFrame(LEE_title)
GUO_title_df = pd.DataFrame(GUO_title)
YANG_title_df = pd.DataFrame(YANG_title)
TAI_title_df = pd.DataFrame(TAI_title)
LIN_title_df = pd.DataFrame(LIN_title)

# %%
Gossip_title_df = pd.DataFrame(Gossip_title)

# %%
# check
x = Gossip_title_df[0][0:499]
x[1]
# Out:
# '新聞南方澳黑鮪魚因疫慘跌拍賣價創新低'

# %%
# !pip3 install bixin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bixin
#   Downloading bixin-0.0.6.tar.gz (3.6 MB)
#      |████████████████████████████████| 3.6 MB 11.0 MB/s
# Collecting jieba_fast>=0.53
#   Downloading jieba_fast-0.53.tar.gz (7.5 MB)
#      |████████████████████████████████| 7.5 MB 48.6 MB/s
# Building wheels for collected packages: bixin, jieba-fast
#   Building wheel for bixin (setup.py) ... done
#   Created wheel for bixin: filename=bixin-0.0.6-py3-none-any.whl size=3584503 sha256=9e94ed9c1679d066986cfbbaa15cabaca7b9a17a14c21de5591a972981d1695e
#   Stored in directory: /root/.cache/pip/wheels/fa/38/ba/3503d48a621ffa6fe0bfd53faa34d75a9dcfa7567a9ab83a8d
#   Building wheel for jieba-fast (setup.py) ... done
#   Created wheel for jieba-fast: filename=jieba_fast-0.53-cp37-cp37m-linux_x86_64.whl size=7658301 sha256=596f93ebf862d4d6bcabfa59dda8015dd26fa0db3117506b4f0637c06232ad9c
#   Stored in directory: /root/.cache/pip/wheels/40/87/79/51f40efba790e648b37d3f3a7c03fe0b2c93973d9ed0076bae
# Successfully built bixin jieba-fast
# Installing collected packages: jieba-fast, bixin
# Successfully installed bixin-0.0.6 jieba-fast-0.53

# %%
from bixin import predict
# #text ="幸福每时每刻都会像路边的乞丐一样出现在你面前。要是你觉得你所梦想的幸福不是这样的，因而断言你的幸福已死亡，你只接受符合你的原则和心愿的幸福，那么你就会落得不幸。"
#     # 出自安德烈·纪德《人间食粮》
# score = []
# for i in range(len(LEE_title_df)):
#   # score = predict(LEE_title_df[0][i])
#   score.append(predict(LEE_title_df[0][i]))
#     # sentiment score: 0.42
# # score

# %%
# !pip3 install KeyMojiAPI
from KeyMojiAPI import KeyMoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting KeyMojiAPI
#   Downloading KeyMojiAPI-1.0.4-py3-none-any.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 15.2 MB/s
# Collecting python-rapidjson>=0.9.4
#   Downloading python_rapidjson-1.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 36.0 MB/s
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.7/dist-packages (from KeyMojiAPI) (1.21.6)
# Collecting scipy>=1.5.4
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 328 kB/s
# Collecting matplotlib>=3.3.3
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 51.0 MB/s
# Collecting requests>=2.25.1
#   Downloading requests-2.28.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.6 MB/s
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 64.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (1.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.3->KeyMojiAPI) (4.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->KeyMojiAPI) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (2022.5.18.1)
# Installing collected packages: fonttools, scipy, requests, python-rapidjson, matplotlib, KeyMojiAPI
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed KeyMojiAPI-1.0.4 fonttools-4.33.3 matplotlib-3.5.2 python-rapidjson-1.6 requests-2.28.0 scipy-1.7.3

# %%
# from KeyMojiAPI import KeyMoji
# # 若您是使用 Docker 版本，無須填入 username, keymoji_key 參數
# text = clean(text)
keymoji = KeyMoji(username="", keymojiKey="")
temp = Gossip_title_df[0:500]
KeyMoji_score = []
for i in range(0, 500):
  KeyMoji_score.append(keymoji.sense8(temp[0][i]))

#result = keymoji.sense8(LEE_title_df[0][0])
#print(result)
KeyMoji_score
# Out:
# [{'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦剛上大學小大1應該先買筆電還是勁戰掛'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.3503,
#     'Anticipation': 8.4997,
#     'Disgust': 1.1538,
#     'Fear': 0.0951,
#     'Joy': 7.8836,
#     'Sadness': 0.8888,
#     'Surprise': 8.2384,
#     'Trust': 7.1818,
#     'input_str': '新聞南方澳黑鮪魚因疫慘跌拍賣價創新低'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦應該限制只有已婚婦女可以當女老師嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦干飯兄弟的辣椒醬是啥牌子'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 3.0462,
#     'Anticipation': 0.0126,
#     'Disgust': 2.9018,
#     'Fear': 3.0894,
#     'Joy': 0.4548,
#     'Sadness': 3.0134,
#     'Surprise': 0.8675,
#     'Trust': 2.1934,
#     'input_str': 'Re問卦e做的哪一件事最不能忍'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 2.5895,
#     'Anticipation': 0.5928,
#     'Disgust': 2.6721,
#     'Fear': 2.5604,
#     'Joy': 1.034,
#     'Sadness': 3.1696,
#     'Surprise': 1.2209,
#     'Trust': 1.4015,
#     'input_str': 'Re新聞穿瑜珈褲出門運動被媽罵沒家教網嘆長輩接受度低'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞全球房市未來2年看壞專家估對首'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.964,
#     'Anticipation': 0.5458,
#     'Disgust': 1.6315,
#     'Fear': 1.5675,
#     'Joy': 0.5193,
#     'Sadness': 2.4226,
#     'Surprise': 0.4508,
#     'Trust': 0.9497,
#     'input_str': '問卦路被不認識的人封了怎辦'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0928,
#     'Anticipation': 5.8542,
#     'Disgust': 0.46,
#     'Fear': 0.0518,
#     'Joy': 6.9477,
#     'Sadness': 0.4585,
#     'Surprise': 6.6412,
#     'Trust': 5.4075,
#     'input_str': '新聞舔牆壁搭配龍舌蘭美餐廳岩鹽磚牆'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦最頂的菱角酥在豐原嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.877,
#     'Anticipation': 0.05,
#     'Disgust': 0.9789,
#     'Fear': 0.6074,
#     'Joy': 0.3218,
#     'Sadness': 0.881,
#     'Surprise': 0.4978,
#     'Trust': 0.6457,
#     'input_str': '本文已被刪除2004'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦上班還有做過什麼事的掛'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦當年大宇資訊是什麼等級的公司'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦在圖書館外面玩球有怎樣嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦是不是4走路實景影片都會很漂亮'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8199,
#     'Anticipation': 5.2649,
#     'Disgust': 0.6363,
#     'Fear': 1.0832,
#     'Joy': 7.0687,
#     'Sadness': 1.8843,
#     'Surprise': 6.4531,
#     'Trust': 4.4425,
#     'input_str': 'Re新聞上班玩北市府科長林育生認錯自請處分'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦無王法了全台剩我沒槍'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.9526,
#     'Anticipation': 0.488,
#     'Disgust': 1.1261,
#     'Fear': 0.9613,
#     'Joy': 0.0941,
#     'Sadness': 0.9209,
#     'Surprise': 0.0171,
#     'Trust': 0.6135,
#     'input_str': 'Re新聞藍委要求幫約美國人影響行政中立涉外人'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦科長薪水多高阿'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦婚宴流水席是不是消失幾年了'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.8601,
#     'Anticipation': 0.9303,
#     'Disgust': 6.2966,
#     'Fear': 1.0162,
#     'Joy': 0.9137,
#     'Sadness': 1.8241,
#     'Surprise': 0.5568,
#     'Trust': 0.7722,
#     'input_str': 'Re問卦身而為人到底一生在追求什麼'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.877,
#     'Anticipation': 0.05,
#     'Disgust': 0.9789,
#     'Fear': 0.6074,
#     'Joy': 0.3218,
#     'Sadness': 0.881,
#     'Surprise': 0.4978,
#     'Trust': 0.6457,
#     'input_str': '本文已被刪除'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re新聞北市府養網軍前後幕僚隔空互槓柯文'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.7485,
#     'Anticipation': 0.0971,
#     'Disgust': 0.7692,
#     'Fear': 0.7349,
#     'Joy': 0.2615,
#     'Sadness': 0.8668,
#     'Surprise': 0.2927,
#     'Trust': 0.4086,
#     'input_str': '問卦準備好要空投跳傘了要注意些什麼'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦有沒有英文字母搭配數字的八卦'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.4806,
#     'Anticipation': 6.2859,
#     'Disgust': 1.3433,
#     'Fear': 0.0968,
#     'Joy': 5.7485,
#     'Sadness': 0.1481,
#     'Surprise': 4.2345,
#     'Trust': 5.9104,
#     'input_str': '問卦妹妹說想去看捍衛戰士2'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞日月潭出現大頭鰱浮頭異象專家曝真'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.3096,
#     'Anticipation': 0.05,
#     'Disgust': 0.1772,
#     'Fear': 0.038,
#     'Joy': 0.2198,
#     'Sadness': 0.2356,
#     'Surprise': 0.5439,
#     'Trust': 0.0874,
#     'input_str': '問卦25號宇宙的行為沉淪在台灣出現'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.1827,
#     'Anticipation': 1.1413,
#     'Disgust': 1.2603,
#     'Fear': 1.2919,
#     'Joy': 1.0271,
#     'Sadness': 2.3032,
#     'Surprise': 0.8063,
#     'Trust': 0.9793,
#     'input_str': '新聞就不能建我隔壁全臺唯一沒有火化場的彰'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.4257,
#     'Anticipation': 0.6954,
#     'Disgust': 0.3154,
#     'Fear': 0.2727,
#     'Joy': 0.7921,
#     'Sadness': 0.3465,
#     'Surprise': 0.7527,
#     'Trust': 0.9764,
#     'input_str': '問卦女警車禍事件說明了車體險的重要性'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8199,
#     'Anticipation': 5.2649,
#     'Disgust': 0.6363,
#     'Fear': 1.0832,
#     'Joy': 7.0687,
#     'Sadness': 1.8843,
#     'Surprise': 6.4531,
#     'Trust': 4.4425,
#     'input_str': 'Re新聞上班玩北市府科長林育生認錯自請處分1'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.333,
#     'Anticipation': 0.05,
#     'Disgust': 1.4461,
#     'Fear': 1.3492,
#     'Joy': 0.3816,
#     'Sadness': 1.3492,
#     'Surprise': 0.8164,
#     'Trust': 0.2776,
#     'input_str': 'Re問卦張上淳多久沒出現了'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞哈佛專家找到逆齡開關將朝人體臨床試驗邁'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 7.9149,
#     'Anticipation': 0.0958,
#     'Disgust': 8.4788,
#     'Fear': 8.7356,
#     'Joy': 2.2143,
#     'Sadness': 9.9193,
#     'Surprise': 2.5137,
#     'Trust': 2.0318,
#     'input_str': '問卦老大教我們喝酒'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.05,
#     'Anticipation': 0.2584,
#     'Disgust': 0.0694,
#     'Fear': 0.073,
#     'Joy': 0.5488,
#     'Sadness': 0.4973,
#     'Surprise': 0.1354,
#     'Trust': 0.5208,
#     'input_str': 'Re新聞兒童疫苗接種站最後一天陳時中效'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 8.0592,
#     'Anticipation': 0.0975,
#     'Disgust': 8.7758,
#     'Fear': 8.5495,
#     'Joy': 1.7916,
#     'Sadness': 9.3892,
#     'Surprise': 2.7402,
#     'Trust': 1.8817,
#     'input_str': '問卦你們知道中國人可悲的是不能說真話'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞柯市府網軍之亂延燒四叉貓再揪出1人科'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦e以後還有辦法再婚嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re新聞柯市府網軍之亂延燒四叉貓再揪出1人科'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦台電工程都在0點到6點做'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8199,
#     'Anticipation': 5.2649,
#     'Disgust': 0.6363,
#     'Fear': 1.0832,
#     'Joy': 7.0687,
#     'Sadness': 1.8843,
#     'Surprise': 6.4531,
#     'Trust': 4.4425,
#     'input_str': 'Re新聞上班玩北市府科長林育生認錯自請處分2'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦高端是不是真的很頂啊'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦啤酒風味ee飲料是誰在喝'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦日本麥當勞為什麼餐點比台灣多'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦有人還記得嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.4178,
#     'Anticipation': 0.5142,
#     'Disgust': 7.4508,
#     'Fear': 6.7417,
#     'Joy': 0.1086,
#     'Sadness': 5.6222,
#     'Surprise': 0.0931,
#     'Trust': 1.568,
#     'input_str': 'Re問卦如何消滅夜市啊'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦e以後還有辦法再婚嗎1'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦新冠後遺症會持續多久啊'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 5.6641,
#     'Anticipation': 0.1819,
#     'Disgust': 6.395,
#     'Fear': 5.8827,
#     'Joy': 0.0934,
#     'Sadness': 5.9245,
#     'Surprise': 0.9531,
#     'Trust': 1.7165,
#     'input_str': '問卦明天回台灣該注意什麼'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦上班滑懺悔區'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦獵巫基層公務員是在敗票吧'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦玩具槍有辦法射穿人體嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.7672,
#     'Anticipation': 0.05,
#     'Disgust': 1.3847,
#     'Fear': 1.3852,
#     'Joy': 0.6068,
#     'Sadness': 1.5458,
#     'Surprise': 0.4836,
#     'Trust': 0.98,
#     'input_str': '問卦第一次知道少女時代會內鬥有多震撼'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.465,
#     'Anticipation': 0.095,
#     'Disgust': 7.6099,
#     'Fear': 6.472,
#     'Joy': 0.1937,
#     'Sadness': 6.4574,
#     'Surprise': 0.0542,
#     'Trust': 2.3059,
#     'input_str': '新聞曾破史上最大68億運毒案英雄淪性侵犯'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦一日租車怎麼租最划算'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.4178,
#     'Anticipation': 0.5142,
#     'Disgust': 7.4508,
#     'Fear': 6.7417,
#     'Joy': 0.1086,
#     'Sadness': 5.6222,
#     'Surprise': 0.0931,
#     'Trust': 1.568,
#     'input_str': 'Re問卦如何消滅夜市啊1'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦真的有女生會想嫁給身障人士嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞總統臉書引網友嗆聲嘆小孩老人飛官走了'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.7408,
#     'Anticipation': 0.6238,
#     'Disgust': 6.3428,
#     'Fear': 6.1807,
#     'Joy': 0.4628,
#     'Sadness': 6.3031,
#     'Surprise': 1.2038,
#     'Trust': 1.686,
#     'input_str': '新聞確診死者火化爭議家屬要政府給道歉嘆'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.385,
#     'Anticipation': 0.1307,
#     'Disgust': 1.6953,
#     'Fear': 1.5861,
#     'Joy': 0.1851,
#     'Sadness': 2.378,
#     'Surprise': 0.0775,
#     'Trust': 0.3842,
#     'input_str': '問卦上班不能做的事有哪些'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 5.2903,
#     'Anticipation': 0.0978,
#     'Disgust': 5.7269,
#     'Fear': 5.9446,
#     'Joy': 1.1943,
#     'Sadness': 6.4729,
#     'Surprise': 0.7803,
#     'Trust': 0.9802,
#     'input_str': '問卦炸串根本屌打鹽酥雞吧'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞少年與爸媽吵架一怒變蜘蛛人37樓徒'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.6368,
#     'Anticipation': 6.2039,
#     'Disgust': 1.4678,
#     'Fear': 0.59,
#     'Joy': 6.554,
#     'Sadness': 0.7634,
#     'Surprise': 6.1856,
#     'Trust': 6.7457,
#     'input_str': '問卦閩客粵哪種語言比較有用'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦日本連鎖眼鏡為何在台灣做得起來'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦對素雞頭有什麼看法'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦分析是不是該來第三波了'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re新聞北市府養網軍前後幕僚隔空互槓柯'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦酒店妹找你借錢要借嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦屁精被討厭是因為很髒嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.4528,
#     'Anticipation': 0.0497,
#     'Disgust': 0.4199,
#     'Fear': 0.4363,
#     'Joy': 0.135,
#     'Sadness': 0.5662,
#     'Surprise': 0.18,
#     'Trust': 0.0973,
#     'input_str': '問卦連假結束該做什麼讓心情更差'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 9.0788,
#     'Anticipation': 0.3485,
#     'Disgust': 6.4812,
#     'Fear': 0.3763,
#     'Joy': 0.1332,
#     'Sadness': 0.6282,
#     'Surprise': 0.1466,
#     'Trust': 0.3734,
#     'input_str': '問卦上市櫃公司必須公布員工不能討論的薪資'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦e為什麼不換掉啊'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦網軍的概念是不是被抽換了'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦粽子為什麼要做成三角錐的形狀'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦如果做疫調是新冠尷尬還是猴痘'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦上班滑慚悔區'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8199,
#     'Anticipation': 5.2649,
#     'Disgust': 0.6363,
#     'Fear': 1.0832,
#     'Joy': 7.0687,
#     'Sadness': 1.8843,
#     'Surprise': 6.4531,
#     'Trust': 4.4425,
#     'input_str': 'Re新聞上班玩北市府科長林育生認錯自請處分3'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦這次狂洗白網軍是不是智力測驗'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.0141,
#     'Anticipation': 1.4902,
#     'Disgust': 1.2057,
#     'Fear': 0.9613,
#     'Joy': 1.2562,
#     'Sadness': 0.8984,
#     'Surprise': 2.133,
#     'Trust': 7.1124,
#     'input_str': '已被刪除濫用'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦快十年前大學生零用錢只要5000是唬爛嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦台灣網軍軍力算世界前段班嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.877,
#     'Anticipation': 0.05,
#     'Disgust': 0.9789,
#     'Fear': 0.6074,
#     'Joy': 0.3218,
#     'Sadness': 0.881,
#     'Surprise': 0.4978,
#     'Trust': 0.6457,
#     'input_str': '本文已被刪除0913'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦的抗壓性是在神山練出來的嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.095,
#     'Anticipation': 6.4505,
#     'Disgust': 1.3833,
#     'Fear': 1.4001,
#     'Joy': 8.1031,
#     'Sadness': 0.7907,
#     'Surprise': 6.9502,
#     'Trust': 6.0116,
#     'input_str': '問卦台灣有誰適合參加極限體能王'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.877,
#     'Anticipation': 0.05,
#     'Disgust': 0.9789,
#     'Fear': 0.6074,
#     'Joy': 0.3218,
#     'Sadness': 0.881,
#     'Surprise': 0.4978,
#     'Trust': 0.6457,
#     'input_str': '本文已被刪除'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.1946,
#     'Anticipation': 1.0495,
#     'Disgust': 7.1049,
#     'Fear': 7.0477,
#     'Joy': 0.3477,
#     'Sadness': 7.1809,
#     'Surprise': 0.0937,
#     'Trust': 2.4046,
#     'input_str': '問卦幹帳號拿回來了啦幹'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8199,
#     'Anticipation': 5.2649,
#     'Disgust': 0.6363,
#     'Fear': 1.0832,
#     'Joy': 7.0687,
#     'Sadness': 1.8843,
#     'Surprise': 6.4531,
#     'Trust': 4.4425,
#     'input_str': 'Re新聞上班玩北市府科長林育生認錯自請處分4'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.0742,
#     'Anticipation': 0.1554,
#     'Disgust': 1.0651,
#     'Fear': 0.9844,
#     'Joy': 0.1798,
#     'Sadness': 1.0903,
#     'Surprise': 0.2024,
#     'Trust': 0.2476,
#     'input_str': '問卦烏俄戰爭甚麼時候能結束'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.0059,
#     'Anticipation': 0.476,
#     'Disgust': 1.2326,
#     'Fear': 0.8508,
#     'Joy': 0.3411,
#     'Sadness': 1.4452,
#     'Surprise': 0.335,
#     'Trust': 1.212,
#     'input_str': '問卦達摩大師會怎樣開導e'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.291,
#     'Anticipation': 0.0604,
#     'Disgust': 0.9442,
#     'Fear': 1.8381,
#     'Joy': 0.9157,
#     'Sadness': 1.468,
#     'Surprise': 0.106,
#     'Trust': 0.7561,
#     'input_str': '問卦如果義勇軍其實都只是自己手下'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.4423,
#     'Anticipation': 0.05,
#     'Disgust': 0.4611,
#     'Fear': 0.372,
#     'Joy': 0.169,
#     'Sadness': 0.9052,
#     'Surprise': 0.1681,
#     'Trust': 1.2128,
#     'input_str': 'Re問卦國中班排第一名現在竟然在做保全'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.7408,
#     'Anticipation': 0.6238,
#     'Disgust': 6.3428,
#     'Fear': 6.1807,
#     'Joy': 0.4628,
#     'Sadness': 6.3031,
#     'Surprise': 1.2038,
#     'Trust': 1.686,
#     'input_str': 'Re新聞確診死者火化爭議家屬要政府給道歉嘆'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦51歲的珍妮佛康納莉你可以嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re新聞柯市府網軍之亂延燒四叉貓再揪出1人科1'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞把閨密兒當牛郎寵遭甩抓狂'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.4367,
#     'Anticipation': 0.3815,
#     'Disgust': 0.1804,
#     'Fear': 0.05,
#     'Joy': 0.6524,
#     'Sadness': 0.368,
#     'Surprise': 1.2311,
#     'Trust': 0.2344,
#     'input_str': '問卦金庸的武俠遊戲'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.4539,
#     'Anticipation': 0.1184,
#     'Disgust': 0.4234,
#     'Fear': 0.476,
#     'Joy': 0.9415,
#     'Sadness': 0.933,
#     'Surprise': 0.7534,
#     'Trust': 0.917,
#     'input_str': '問卦朋友一個一個離婚'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.6557,
#     'Anticipation': 0.7354,
#     'Disgust': 0.8092,
#     'Fear': 0.7591,
#     'Joy': 0.7436,
#     'Sadness': 0.8036,
#     'Surprise': 0.8723,
#     'Trust': 0.8753,
#     'input_str': '問卦油價也太貴誰該負責'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.7638,
#     'Anticipation': 7.2969,
#     'Disgust': 0.2988,
#     'Fear': 0.094,
#     'Joy': 8.3266,
#     'Sadness': 1.5347,
#     'Surprise': 7.5942,
#     'Trust': 6.3877,
#     'input_str': '爆卦Re納達爾奪下法網冠軍'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.877,
#     'Anticipation': 0.05,
#     'Disgust': 0.9789,
#     'Fear': 0.6074,
#     'Joy': 0.3218,
#     'Sadness': 0.881,
#     'Surprise': 0.4978,
#     'Trust': 0.6457,
#     'input_str': '本文已被刪除'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦唐詩要用台語讀是真的嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦法網最紅的球員是梅西嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0205,
#     'Anticipation': 5.7681,
#     'Disgust': 0.0931,
#     'Fear': 0.0982,
#     'Joy': 6.9153,
#     'Sadness': 1.1459,
#     'Surprise': 6.3469,
#     'Trust': 5.5408,
#     'input_str': '爆卦紅土地公又贏了'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.3416,
#     'Anticipation': 0.1188,
#     'Disgust': 6.286,
#     'Fear': 5.9765,
#     'Joy': 0.4619,
#     'Sadness': 5.9504,
#     'Surprise': 0.8909,
#     'Trust': 0.7641,
#     'input_str': '新聞醫估單日死亡將破200例陳時中不認為'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦福隆便當哪一家最好吃啊'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '新聞快訊2蛇入侵焦了台鐵台中電車線故'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 4.3285,
#     'Anticipation': 0.4463,
#     'Disgust': 4.9,
#     'Fear': 4.5388,
#     'Joy': 0.0368,
#     'Sadness': 4.2347,
#     'Surprise': 0.8637,
#     'Trust': 0.096,
#     'input_str': '新聞嘉義女孩朱婕瑀台灣首位三千公尺障礙賽'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 5.0964,
#     'Anticipation': 0.095,
#     'Disgust': 5.7211,
#     'Fear': 6.0712,
#     'Joy': 0.1096,
#     'Sadness': 6.648,
#     'Surprise': 1.3181,
#     'Trust': 1.0459,
#     'input_str': '問卦外國餐廳居然超級平價網嘆台灣賣太貴'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦為什麼這次北市府網軍會燒起來'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 6.7408,
#     'Anticipation': 0.6238,
#     'Disgust': 6.3428,
#     'Fear': 6.1807,
#     'Joy': 0.4628,
#     'Sadness': 6.3031,
#     'Surprise': 1.2038,
#     'Trust': 1.686,
#     'input_str': 'Re新聞確診死者火化爭議家屬要政府給道歉嘆1'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': 'Re問卦的抗壓性是在神山練出來的嗎1'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '問卦兒歌三百首可以感化乖乖e嗎'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8199,
#     'Anticipation': 5.2649,
#     'Disgust': 0.6363,
#     'Fear': 1.0832,
#     'Joy': 7.0687,
#     'Sadness': 1.8843,
#     'Surprise': 6.4531,
#     'Trust': 4.4425,
#     'input_str': 'Re新聞上班玩北市府科長林育生認錯自請處分5'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
# ...
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 3}]

# %%
# # check
KeyMoji_score[112]['results']
# Out:
# [{'Anger': 0.8199,
#   'Anticipation': 5.2649,
#   'Disgust': 0.6363,
#   'Fear': 1.0832,
#   'Joy': 7.0687,
#   'Sadness': 1.8843,
#   'Surprise': 6.4531,
#   'Trust': 4.4425,
#   'input_str': 'Re新聞上班玩北市府科長林育生認錯自請處分5'}]

# %%
x = []
KeyMoji_result = []
# 在range 中填入成功index的range
for i in range(0,112):
  x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
          KeyMoji_score[i]['results'][0]['Anger'],
          KeyMoji_score[i]['results'][0]['Anticipation'],
          KeyMoji_score[i]['results'][0]['Disgust'],
          KeyMoji_score[i]['results'][0]['Fear'],
          KeyMoji_score[i]['results'][0]['Joy'],
          KeyMoji_score[i]['results'][0]['Sadness'],
          KeyMoji_score[i]['results'][0]['Surprise'],
          KeyMoji_score[i]['results'][0]['Trust']])
  KeyMoji_result.append(x)

# %%
roll_no = range(99,100)
pd.DataFrame(KeyMoji_result, index = roll_no)

# %%
def add_to_csv(data, path):
  with open(path, mode='a', newline='', encoding='utf8') as cfa:
      data.to_csv(cfa,header=0) # index = False

# %%
# 存入CSV
Gossip_KeyMoji_score = pd.DataFrame(KeyMoji_result, index=roll_no)
Gossip_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_Gossip.csv"

path = save_path_Keymoji + name
add_to_csv(Gossip_KeyMoji_score, path)

# %%
# 存入CSV
Gossip_KeyMoji_score = pd.DataFrame(KeyMoji_result)
Gossip_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_Gossip.csv"

path = save_path_Keymoji + name
store_to_csv_df(Gossip_KeyMoji_score, path)

# %%
def My_KeyMoji(data):
  # 若您是使用 Docker 版本，無須填入 username, keymoji_key 參數
  keymoji = KeyMoji(username="", keymojiKey="")

  KeyMoji_score = []
  for i in range(len(data)):
    KeyMoji_score.append(keymoji.sense8(data[i]))
  print(KeyMoji_score)
  
  x = []
  for i in range(len(KeyMoji_score)):
    x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
            KeyMoji_score[i]['results'][0]['Anger'],
            KeyMoji_score[i]['results'][0]['Anticipation'],
            KeyMoji_score[i]['results'][0]['Disgust'],
            KeyMoji_score[i]['results'][0]['Fear'],
            KeyMoji_score[i]['results'][0]['Joy'],
            KeyMoji_score[i]['results'][0]['Sadness'],
            KeyMoji_score[i]['results'][0]['Surprise'],
            KeyMoji_score[i]['results'][0]['Trust']])
    KeyMoji_result.append(x)

# %%
# Gossip
KeyMoji_result = []
x = Gossip_title_df[0][0:199]
My_KeyMoji(x)
Gossip_KeyMoji_score = pd.DataFrame(KeyMoji_result)
Gossip_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_Gossip199.csv"

path = save_path_Keymoji + name
store_to_csv_df(Gossip_KeyMoji_score, path)
# Out:
# [{'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 1 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-d947c9c60b0a> in <module>()
#       2 KeyMoji_result = []
#       3 x = Gossip_title_df[0][0:199]
# ----> 4 My_KeyMoji(x)
#       5 Gossip_KeyMoji_score = pd.DataFrame(KeyMoji_result)
#       6 Gossip_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
#
# <ipython-input-15-8cb9688b26b8> in My_KeyMoji(data)
#      10   x = []
#      11   for i in range(len(KeyMoji_score)):
# ---> 12     x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
#      13             KeyMoji_score[i]['results'][0]['Anger'],
#      14             KeyMoji_score[i]['results'][0]['Anticipation'],
#
# KeyError: 'results'

# %%
# LEE
KeyMoji_result = []
My_KeyMoji(LEE_title_df)
LEE_KeyMoji_score = pd.DataFrame(KeyMoji_result)
LEE_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_LEE.csv"

path = save_path_Keymoji + name
store_to_csv_df(LEE_KeyMoji_score, path)

# %%
# GUO
KeyMoji_result = []
My_KeyMoji(GUO_title_df)
GUO_KeyMoji_score = pd.DataFrame(KeyMoji_result)
GUO_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_GUO.csv"

path = save_path_Keymoji + name
store_to_csv_df(GUO_KeyMoji_score, path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-72a19fb04026> in <module>()
#       1 # GUO
#       2 KeyMoji_result = []
# ----> 3 My_KeyMoji(GUO_title_df)
#       4 GUO_KeyMoji_score = pd.DataFrame(KeyMoji_result)
#       5 GUO_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
#
# <ipython-input-17-4a8e3d9b529f> in My_KeyMoji(data)
#      10   x = []
#      11   for i in range(len(KeyMoji_score)):
# ---> 12     x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
#      13             KeyMoji_score[i]['results'][0]['Anger'],
#      14             KeyMoji_score[i]['results'][0]['Anticipation'],
#
# KeyError: 'results'

# %%
# YANG
KeyMoji_result = []
My_KeyMoji(YANG_title_df)
YANG_KeyMoji_score = pd.DataFrame(KeyMoji_result)
YANG_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_YANG.csv"

path = save_path_Keymoji + name
store_to_csv_df(YANG_KeyMoji_score, path)

# %%
# TAI
KeyMoji_result = []
My_KeyMoji(TAI_title_df)
TAI_KeyMoji_score = pd.DataFrame(KeyMoji_result)
TAI_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_TAI.csv"

path = save_path_Keymoji + name
store_to_csv_df(TAI_KeyMoji_score, path)

# %%
# LIN
KeyMoji_result = []
My_KeyMoji(LIN_title_df)
LIN_KeyMoji_score = pd.DataFrame(KeyMoji_result)
LIN_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_LIN.csv"

path = save_path_Keymoji + name
store_to_csv_df(LIN_KeyMoji_score, path)

# %%
# LEE_KeyMoji_score = pd.DataFrame(LEE_KeyMoji_score)
x = []
KeyMoji_result = []
for i in range(len(KeyMoji_score)):
  x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
          KeyMoji_score[i]['results'][0]['Anger'],
          KeyMoji_score[i]['results'][0]['Anticipation'],
          KeyMoji_score[i]['results'][0]['Disgust'],
          KeyMoji_score[i]['results'][0]['Fear'],
          KeyMoji_score[i]['results'][0]['Joy'],
          KeyMoji_score[i]['results'][0]['Sadness'],
          KeyMoji_score[i]['results'][0]['Surprise'],
          KeyMoji_score[i]['results'][0]['Trust']])
  KeyMoji_result.append(x)

YANG_KeyMoji_score = pd.DataFrame(KeyMoji_result)
YANG_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_YANG.csv"

path = save_path + name
store_to_csv_df(YANG_KeyMoji_score, path)

# %%
# LEE_KeyMoji_score.columns = ['title','Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
# LEE_KeyMoji_score

# %%
# name = "KeyMoji_score_LEE.csv"

# path = save_path + name
# store_to_csv_df(LEE_KeyMoji_score, path)

# %%
print(result)

keymoji.keymoji2visual(result)

# %%
result = keymoji.tension(text)
print(result)

# %%
keymoji.keymoji2visual(result)
