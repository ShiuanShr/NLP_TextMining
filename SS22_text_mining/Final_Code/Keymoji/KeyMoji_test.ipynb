# %%
#text = "染疫輕症明明就該投輝瑞藥，結果現在都是叫輕症病人回家睡覺自己吃感冒藥，不知道為什麼輝瑞開藥領藥流程這麼麻煩，數量也根本不夠，導致普通人都領不到 還一直洗處方洗副作用，輕症變中重症然後就掛了 算誰的鍋？自己活該為什麼要染疫嗎？"
text = "桌球國手「小林同學」林昀儒驚傳返國採檢陽性反應確診。根據民視新聞報導，林昀儒剛結束在卡達的WTT球星挑戰賽，1日晚間搭機經泰國轉機返回台灣，抵達桃園機場進行落地採檢驗出「陽性」反應。對此消息林昀儒媽媽沒有否認，僅回應還在等待消息，謝謝大家關心。桌球國手「小林同學」林昀儒與國手鄭怡靜組成黃金混雙，31日在WTT球星挑戰賽決賽，再度對決法國組合黎貝森(Emmanuel Lebesson)／袁嘉楠，最終林昀儒／鄭怡靜可惜遭到對手直落三，收穫亞軍。"
# text = "戴資穎搭經濟艙賴清德道歉代表國家"

# %%
import csv
import pandas as pd
from string import punctuation
from wordcloud import STOPWORDS
import numpy as np 
import matplotlib.pyplot as plt
import re

# %%
#Mount google drive to google colab virtual machine
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ## 自建停用字
# my_stop_words = ['：','。','。','、','※','【','】',',','，','，','※','※', '」']
# term_stopwords = ['什麼','可以','我們','挑選','篇文章', '備註', '是', '新聞網','或', '的', '某' ,'啦', '分', '等', '才能','可以','我們','挑選','篇文章','你',
#         '知道','任何','如果','而且','不會','。',
#         '從來','外有','不論','記量','從來','只是','還是','这是','以便',
#         '放在','問個','同時','需登','有些','不用','一定','什麼',''
#         ,'運動給'
#         ,'結果'
#         ,'行為'
#         ,'另一台'
#         ,'这次','你','我','他','上次','']
# title_stopwords = ['新聞']
# special_sign = ['◆','▆','▍','▋','▲','◤','▼','▲','▲','◣','▎','◢', '～', '○', '●', '▼', '▲', '->', ':',
#                 '.','~~','!','?', '.', '/', '\ ']
# full_stopwords = list(STOPWORDS) + term_stopwords + special_sign + my_stop_words
# punctuation_str = punctuation
# punctuation_str
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def token_pack(text):
  ws_results = ws([text])
  pos_results = pos(ws_results)
  ner_results = ner(ws_results, pos_results)
  # print('\nws result: \n')
  # print(ws_results)
  # print('\nPOS result: \n')
  # print(pos_results)
  # for name in ner_results[0]:
  #   print(name)
  # 這邊我們直接丟掉NER與POS的結果
  text = ws_results
  return text 

def data_cleaning(str_list):
  string_content = str_list
  article_1 = [article.replace('\n', '') for article in string_content]
  tokens_list = [ token_pack(article) for article in article_1]
  clean_sentences = []
  for article in tokens_list:
    clean_tokens = []
    for _ in article:
      for token in _:
        # 去除token所有半形空白
        token = token.replace(' ', '')
        # 前後去除空白 #去除中英夾雜 #去除純數字
        if token.strip() != "" and not token.encode().isalpha()  and token.isdigit() == False:
          # 去除自建停用字
          if not token in full_stopwords:
            # 去除英文半形標點符號  #去除中文之標點符號
            if  not token in punctuation and not token in punctuation_str:
              clean_tokens.append(token)
      if len(clean_tokens)>0:
        clean_sentences.append(clean_tokens)
  return clean_sentences

# %%
def clean(string_content):
  article_1 = [article.replace('\n', '') for article in string_content]
#  [、_ =\ \\ [\ ] ; ' ，. / ~ ! @ # $ % ^ & *  + | ? > < 「 :{}]

  final_list = [re.sub('[^\u4E00-\u9FA50-9 + ]', '', i) for i in article_1] # ，! @ # ? & ? > < 「」」「 {}
  final_list = [re.sub(' ', '', i) for i in final_list]

  return final_list

# %%
# PATH
import_pwd = '/content/drive/Shareddrives/Text Mining/CSV/Summary/Stage1/'
save_path_title = "/content/drive/Shareddrives/Text Mining/CSV/temp_Title_Joanne/"
save_path_Keymoji = "/content/drive/Shareddrives/Text Mining/CSV/temp_keymoji_J/"

# %%
def store_to_csv(data, path):
  with open(path, 'w', newline='') as csvfile:
      writer = csv.writer(csvfile)
      writer.writerow(data)

# %%
def store_to_csv_df(data, path):
  with open(path, 'w', encoding = 'utf-8-sig') as f:
    data.to_csv(f)

# %%
LEE = pd.read_csv(import_pwd +'All_LEE.csv')
x = clean(LEE['limited_Bert'])
x
# Out:
# ['李智凱秀妻子送他歲生日豪禮要當爸三立李鴻典台北報導恭喜李智凱秀妻子送他歲生日豪禮要當爸爸了完整新聞內文恭喜再恭喜歲體操國手鞍馬王子李智凱今日晚間在臉書曬出照片表示自己即將升格為人父照片中是他跟和妻子一起拿著超音波圖向粉絲分享這個天大好消',
#  '台灣首位世界第鞍馬王子李智凱林岳甫台灣首位世界第鞍馬王子李智凱我會繼續努力完整新聞內文在東京奧運勇奪鞍馬銀牌為台灣寫下歷史新頁鞍馬王子李智凱如今再度締造生涯里程碑榮登國際體操總會鞍馬項目排名世界第他說我會繼續努力保持',
#  '李智凱登鞍馬世界第恩師林育信報喜游郁香李智凱登鞍馬世界第恩師林育信報喜希望鼓勵小選手追夢完整新聞內文鞍馬王子李智凱以招牌動作湯瑪士迴旋奪下東奧銀牌完美落地讓國人一起見證他與恩師林育信年辛苦累積成果師徒兩人擁抱畫面感動人心林育信今日',
#  '台灣李智凱奧運體操為什麼能贏歐美中國歐美中國算是體操大國歐美中國也投資很多資源在體操為什麼在台灣培訓被台灣教練訓練李智凱能夠在奧運體操鞍馬項目勝過歐美中國',
#  '李智凱敢挑戰街健嗎街健肌肉應用最高形式完美控制身體藝術相比之下體操簡直是平淡創意卻企圖以華麗表演來掩飾李智凱雖然拿到奧運銀牌了但是不是還是不敢挑戰街健有沒有卦',
#  '李智凱沒拍過武打片李智凱好像是上屆奧運就很有名選手他顏值和身手尤其是掃堂腿應該很適合拍武打功夫片吧怎麼沒成為男主',
#  '中國體操鞍馬培養不出台灣李智凱等級選手最近覺青真蠻好笑中國拿銀作圖嘲笑中國拿銀牌洗版整天中國拿金金牌數第一關我屁事他國事務這種鴕鳥式愛台看到都覺得羞愧',
#  '中國體操鞍馬培養不出台灣李智凱等級選手引述綠營重新執政之銘言中國不是算體操大國嗎為什麼李智凱能大勝中國鞍馬參賽者李智凱拿鞍馬銀牌中國選手連銅牌都沒有為什麼中國體操鞍馬培養不出台灣李智凱等級選手雖然知道是反串但無聊還是來嗆一下年後老人阿公阿嬤',
#  '中國體操鞍馬培養不出台灣李智凱等級選手中國不是算體操大國嗎為什麼李智凱能大勝中國鞍馬參賽者李智凱拿鞍馬銀牌中國選手連銅牌都沒有為什麼中國體操鞍馬培養不出台灣李智凱等級選手',
#  '李智凱完美落地摘銀謝長廷謝謝他實現他不是第一次提到奧運是他夢想這件事了而是三不五時遇到選手就會把這件事情拿出來說一下對奧運真很執著最早從年爭取舉辦奧運開始就有提到謝長廷台灣應爭取主辦年奧運年遇到日本奧運選手也提過新聞也有報導謝長廷會見日本冰',
#  '李智凱完美落地摘銀彭于晏第一時間引述楓糖蛋糕之銘言李智凱完美落地摘銀彭于晏第一時間傳訊字祝賀娛樂中心詹鎰睿報導我國台灣體操好手李智凱今日成功在東京奧運鞍馬項目奪下銀牌讓台灣全體人民紛紛祝賀慶祝對此曾在電影翻滾吧阿信飾演李智凱教練',
#  '李智凱完美落地摘銀彭于晏第一時間李智凱完美落地摘銀彭于晏第一時間傳訊字祝賀娛樂中心詹鎰睿報導我國台灣體操好手李智凱今日成功在東京奧運鞍馬項目奪下銀牌讓台灣全體人民紛紛祝賀慶祝對此曾在電影翻滾吧阿信飾演李智凱教練林育信男星彭于晏',
#  '李智凱完美落地摘銀謝長廷謝謝他實現這篇噓人真不知道是噓什麼小朋友謝長廷真在中學時期是練體操身為體操選手謝有參加過中上運動會全中運前身及省運會全運會前身前者拿下金牌後者銅牌吊環水準在當時有全國前三實力這些資料上都查到作為一個傑出體操選',
#  '李智凱國中都有交功課各位八卦版廢宅午安事情是這樣啦本帥帥剛剛看新聞看到新聞在訪問鞍馬王子李智凱國中老師他老師說他國中很乖事情都很肯做也不會因為自己練體操就不交作業這時我想到我當年國中時一堆廢物同學放學後都去打咖也都沒有寫作業人家李智凱體育班還',
#  '李智凱完美落地摘銀謝長廷謝謝他實現東森新聞雲杜冠霖李智凱完美落地摘銀謝長廷謝謝他實現了我夢完整新聞內文在東京奧運體操鞍馬項目決賽中鞍馬王子李智凱使出高難度湯瑪士迴旋最後完美落地以總分分奪得銀牌也成為台灣史上首位拿下體操獎牌人對',
#  '李智凱苦練體操年你苦練了什麼引述火箭少女之銘言從翻滾吧男孩歲開始李智凱苦練體操年專精鞍馬項目幾乎年來天天跟鞍馬生活在一起到現在成為翻滾吧男人歲終於奧運奪銀你為了什麼也能夠苦練年呢有些事情不用為了出人頭地或是得獎才有動力一直苦練我認為最重要是心',
#  '李智凱苦練體操年你苦練了什麼從翻滾吧男孩歲開始李智凱苦練體操年專精鞍馬項目幾乎年來天天跟鞍馬生活在一起到現在成為翻滾吧男人歲終於奧運奪銀你為了什麼也能夠苦練年呢',
#  '小戴李智凱對羽球鞍馬貢獻都是開創性吧如題覺得今天兩個奧運銀牌某方面處境有點類似戴資穎和李智凱對羽球和鞍馬分別貢獻從整個運動發展角度來看應該都是開創性歷史性同樣都大大增加了運動觀賞性有趣性開創出新玩法和領域但是也同樣要面臨在爭取',
#  '智智老公指的是李智凱嗎引述張阿月紅茶冰之銘言智智老公醬汁量普通大約有是濃稠米黃色像美乃滋一樣甜度很高有河流楓糖鳶尾草味道非常濃甜吃起來卻一點都不膩就像完美配合精心製作煉乳就像智智老公一樣聰明溫柔總是能給人暖暖驚喜這邊說智智老公指是',
#  '李智凱鞍馬摘銀蔡英文賴清德讚完美落丘采薇李智凱鞍馬摘銀蔡英文賴清德讚完美落地完整新聞內文我國鞍馬王子李智凱今晚在東京奧運鞍馬決賽獲得銀牌為中華隊拿下史上第一面奧運體操獎牌蔡英文總統及副總統賴清德都在臉書上祝賀賴清德表示李智凱湯瑪士迴旋',
#  '中華隊蔡英文李智凱翻滾那秒全台例如中央社至少要有來源或如法新社葉素萍中華隊蔡英文李智凱翻滾那秒全台灣都屏住呼吸完整新聞內文社論特稿都不能貼貼喔中央社葉素萍陳俊華台北日電鞍馬王子李智凱今天在東京奧運體操鞍馬項目摘下銀牌總統蔡英文說',
#  '李智凱奪銀感動落淚用小小力量讓世界看見台灣我已無遺憾李智凱奪銀感動落淚用小小力量讓世界看見台灣我已無遺憾運動雲王真魚日本東京報導鞍馬王子李智凱在年里約奧運不慎落馬儘管仍有心魔但化悲憤為力量年台北世大運奪金年雅加達亞運再奪隊史首',
#  '李智凱戰勝心魔奪銀成功拿出壓箱寶李智凱戰勝心魔奪銀成功拿出壓箱寶完美落地激動落淚年月日王真魚日本東京報導鞍馬王子李智凱在年里約奧運不慎落馬儘管仍有心魔但化悲憤為力量年台北世大運奪金年雅加達亞運再奪隊史首金今年二度闖奧運資格賽鞍馬',
#  '李智凱銀牌今天真是太爽了每推發到爆翻滾吧台灣男孩希望今天晚上羽球有再一面金牌引述蜂蜜優格之銘言就在剛剛李智凱確定拿下銀牌啦李智凱鞍馬個人勇奪銀牌分突破預賽分數可惜輸給英國下一屆繼續加油這個社會一直在談家庭教育以及工作間平衡我辭職之後回',
#  '完美落地李智凱鞍馬奪銀牌台灣體操史上第人完美落地李智凱鞍馬奪銀牌台灣體操史上第人三立新聞王怡翔東京奧運體操鞍馬項目日進行決賽台灣好手李智凱出賽使出高難度湯瑪士迴旋李智凱完美落地總分分雖然無緣金牌但排名第二拿下銀牌是台灣首面體',
#  '李智凱是用胸做鞍馬動作嗎對體操知識全部都來自奧運高手當年分滿分現在也早就不是這規則了雖然印象最深還是主角托卡傑夫前空翻+落地轉體四圈但鞍馬部分最早因為眼鏡仔搞笑溜溜球也很有印象因為俄羅斯教練原因他們都會用胸做體操剛剛李智凱上來之前其他人感覺',
#  '艾迪彭會發文祝賀李智凱嗎不知道他會不會祝賀台灣第一面體操類奧運銀牌尤其是某國吊車尾項目有這方面消息嗎恭喜李智凱拿銀牌',
#  '李智凱鞍馬勇奪銀牌李智凱鞍馬個人勇奪銀牌分突破預賽分數可惜英國太鬼了不然金牌穩穩下一屆繼續加油',
#  '李智凱銀牌就在剛剛李智凱確定拿下銀牌啦李智凱鞍馬個人勇奪銀牌分突破預賽分數可惜輸給英國下一屆繼續加油',
#  '鞍馬決賽李智凱分鞍馬決賽李智凱獲得分目前暫列第二後面還有三名選手沒人比他高分話就銀牌了',
#  '聽說李智凱等等有一招秘密武器剛剛在看女子體操頒獎典禮等一下鞍馬王子就要登場了東森主播一直說李智凱有一招秘密武器動作從來沒有使用過而且難度超高大絕招保證驚天動地有人知道這個神秘大絕招是什麼嗎主角我本來不想用這招加油加油加油',
#  '不愧是奪金希望李智凱以鞍馬資格賽第不愧是奪金希望李智凱以鞍馬資格賽第名晉級決賽李智凱以資格賽最高分晉級鞍馬決賽資照圖片來源新聞網背負奪金希望台灣鞍馬王子李智凱今天在東京奧運體操男子資格賽出賽他在最被看好奪金鞍馬項目再度展現個人最拿手',
#  '中華隊東奧授旗戴資穎李智凱代表蔡英例如至少要有來源或如法新社謝孟儒中華隊東奧授旗戴資穎李智凱代表蔡英文勉勵贈萬加菜金完整新聞內文社論特稿都不能貼貼喔年月日羽球年終賽冠軍戴資穎圖提供謝孟儒第屆東京奧運將於月日至月日舉行我國代表隊備戰已進']

# %%
# LEE
name = "ALL_LEE.csv"
# LEE = pd.read_csv(import_pwd +'LEE_title_output.csv')
LEE = pd.read_csv(import_pwd +'All_LEE.csv')
LEE_title = clean(LEE['limited_Bert'])

path = save_path_title + name
# store_to_csv(LEE_title, path)

# %%
# GUO
name = "ALL_GUO.csv"
# GUO = pd.read_csv(import_pwd +'GUO_title_output.csv')
GUO = pd.read_csv(import_pwd +'All_GUO.csv')
GUO_title = clean(GUO['limited_Bert'])

path = save_path_title + name
# store_to_csv(GUO_title, path)

# %%
# YANG
name = "ALL_YANG.csv"
# YANG = pd.read_csv(import_pwd +'YANG_title_output.csv')
YANG = pd.read_csv(import_pwd +'All_YANG.csv')
YANG_title = clean(YANG['limited_Bert'])

path = save_path_title + name
# store_to_csv(YANG_title, path)

# %%
# TAI
name = "ALL_TAI.csv"
# TAI = pd.read_csv(import_pwd +'TAI_title_output.csv')
TAI = pd.read_csv(import_pwd +'All_TAI.csv')
TAI_title = clean(TAI['limited_Bert'])

path = save_path_title + name
# store_to_csv(TAI_title, path)

# %%
# LIN
name = "ALL_LIN.csv"
# LIN = pd.read_csv(import_pwd +'LIN_title_output.csv')
LIN = pd.read_csv(import_pwd +'All_LIN.csv')
LIN_title = clean(LIN['limited_Bert'])

path = save_path_title + name
# store_to_csv(LIN_title, path)

# %%
# store to dataframe
LEE_title_df = pd.DataFrame(LEE_title)
GUO_title_df = pd.DataFrame(GUO_title)
YANG_title_df = pd.DataFrame(YANG_title)
TAI_title_df = pd.DataFrame(TAI_title)
LIN_title_df = pd.DataFrame(LIN_title)

# %%
# check
LIN_title_df
# Out:
#                                                     0
# 0   小林同學林昀儒驚傳確診陳時中可新聞雲楊晏琳台北報導小林同學林昀儒驚傳確診陳時中可能是陰陰陽陽...
# 1              快訊小林同學林昀儒驚傳確診返驚你老母他有重症嗎需要插管嗎送嗎身體不適嗎驚你媽
# 2   快訊小林同學林昀儒驚傳確診返新聞雲葉國吏快訊小林同學林昀儒驚傳確診返國落地採檢陽性完整新聞內...
# 3   中國玻璃心碎林昀儒鄭怡靜奪冠國旗風波梁偉銘桌球中國玻璃心碎滿地林昀儒鄭怡靜奪冠國旗風波完整新...
# 4   局大戰險勝馬龍讚林昀儒世界最好運動局大戰險勝馬龍讚林昀儒世界最好運動員劉肇育即時報導我國桌球...
# ..                                                ...
# 95  新星林昀儒嘉義建商已贊助年多打多久林宜樟新星林昀儒嘉義建商已贊助年多打多久支持多久完整新聞內...
# 96  林昀儒惜敗日媒點評最大關鍵他賽後自責林昀儒惜敗日媒點評最大關鍵他賽後自責說對不起體育中心歲林...
# 97  酸民害林昀儒沒拿到銅牌好意思引述之銘言選手練了好幾年才有機會站上奧運戴資穎被影響林昀儒進四強...
# 98  林昀儒有贏牌恐俱的心理啊引述之銘言一路看下來明明程度不錯但只要跟和高手過招幾乎都會追平被追平...
# 99  酸民害林昀儒沒拿到銅牌好意思引述之銘言選手練了好幾年才有機會站上奧運戴資穎被影響林昀儒進四強...
#
# [100 rows x 1 columns]

# %%
# !pip3 install bixin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bixin
#   Downloading bixin-0.0.6.tar.gz (3.6 MB)
#      |████████████████████████████████| 3.6 MB 5.3 MB/s
# Collecting jieba_fast>=0.53
#   Downloading jieba_fast-0.53.tar.gz (7.5 MB)
#      |████████████████████████████████| 7.5 MB 25.5 MB/s
# Building wheels for collected packages: bixin, jieba-fast
#   Building wheel for bixin (setup.py) ... done
#   Created wheel for bixin: filename=bixin-0.0.6-py3-none-any.whl size=3584503 sha256=3200fc71fd33b4b4b9efde9af217533cd551754c1159da8384f4778f851ac015
#   Stored in directory: /root/.cache/pip/wheels/fa/38/ba/3503d48a621ffa6fe0bfd53faa34d75a9dcfa7567a9ab83a8d
#   Building wheel for jieba-fast (setup.py) ... done
#   Created wheel for jieba-fast: filename=jieba_fast-0.53-cp37-cp37m-linux_x86_64.whl size=7658311 sha256=b681599b55fd93f5afc9b89f06f6bedc9b10888067f2b2926671182c2377d35a
#   Stored in directory: /root/.cache/pip/wheels/40/87/79/51f40efba790e648b37d3f3a7c03fe0b2c93973d9ed0076bae
# Successfully built bixin jieba-fast
# Installing collected packages: jieba-fast, bixin
# Successfully installed bixin-0.0.6 jieba-fast-0.53

# %%
from bixin import predict
# #text ="幸福每时每刻都会像路边的乞丐一样出现在你面前。要是你觉得你所梦想的幸福不是这样的，因而断言你的幸福已死亡，你只接受符合你的原则和心愿的幸福，那么你就会落得不幸。"
#     # 出自安德烈·纪德《人间食粮》
# score = []
# for i in range(len(LEE_title_df)):
#   # score = predict(LEE_title_df[0][i])
#   score.append(predict(LEE_title_df[0][i]))
#     # sentiment score: 0.42
# # score

# %%
# !pip3 install KeyMojiAPI
from KeyMojiAPI import KeyMoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting KeyMojiAPI
#   Downloading KeyMojiAPI-1.0.4-py3-none-any.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 5.4 MB/s
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.7/dist-packages (from KeyMojiAPI) (1.21.6)
# Collecting matplotlib>=3.3.3
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 8.3 MB/s
# Collecting python-rapidjson>=0.9.4
#   Downloading python_rapidjson-1.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 42.5 MB/s
# Collecting scipy>=1.5.4
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.9 MB/s
# Collecting requests>=2.25.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3.3->KeyMojiAPI) (1.4.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 66.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.3->KeyMojiAPI) (4.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->KeyMojiAPI) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.1->KeyMojiAPI) (1.24.3)
# Installing collected packages: fonttools, scipy, requests, python-rapidjson, matplotlib, KeyMojiAPI
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed KeyMojiAPI-1.0.4 fonttools-4.33.3 matplotlib-3.5.2 python-rapidjson-1.6 requests-2.27.1 scipy-1.7.3

# %%
# from KeyMojiAPI import KeyMoji
# # 若您是使用 Docker 版本，無須填入 username, keymoji_key 參數
# text = clean(text)
keymoji = KeyMoji(username="", keymojiKey="")

KeyMoji_score = []
for i in range(len(LEE_title_df)):
  KeyMoji_score.append(keymoji.sense8(LEE_title_df[0][i]))

#result = keymoji.sense8(LEE_title_df[0][0])
#print(result)
KeyMoji_score
# Out:
# [{'msg': 'Success!',
#   'results': [{'Anger': 0.7251,
#     'Anticipation': 5.4967,
#     'Disgust': 0.447,
#     'Fear': 0.4347,
#     'Joy': 6.0957,
#     'Sadness': 1.3124,
#     'Surprise': 5.8269,
#     'Trust': 5.2276,
#     'input_str': '李智凱秀妻子送他歲生日豪禮要當爸三立李鴻典台北報導恭喜李智凱秀妻子送他歲生日豪禮要當爸爸了完整新聞內文恭喜再恭喜歲體操國手鞍馬王子李智凱今日晚間在臉書曬出照片表示自己即將升格為人父照片中是他跟和妻子一起拿著超音波圖向粉絲分享這個天大好消'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.499,
#     'Anticipation': 7.0486,
#     'Disgust': 0.5004,
#     'Fear': 0.3577,
#     'Joy': 7.2615,
#     'Sadness': 0.8641,
#     'Surprise': 6.1154,
#     'Trust': 6.7392,
#     'input_str': '台灣首位世界第鞍馬王子李智凱林岳甫台灣首位世界第鞍馬王子李智凱我會繼續努力完整新聞內文在東京奧運勇奪鞍馬銀牌為台灣寫下歷史新頁鞍馬王子李智凱如今再度締造生涯里程碑榮登國際體操總會鞍馬項目排名世界第他說我會繼續努力保持'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8893,
#     'Anticipation': 7.668,
#     'Disgust': 1.0379,
#     'Fear': 0.7563,
#     'Joy': 7.2815,
#     'Sadness': 1.3384,
#     'Surprise': 7.0499,
#     'Trust': 6.5321,
#     'input_str': '李智凱登鞍馬世界第恩師林育信報喜游郁香李智凱登鞍馬世界第恩師林育信報喜希望鼓勵小選手追夢完整新聞內文鞍馬王子李智凱以招牌動作湯瑪士迴旋奪下東奧銀牌完美落地讓國人一起見證他與恩師林育信年辛苦累積成果師徒兩人擁抱畫面感動人心林育信今日'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '台灣李智凱奧運體操為什麼能贏歐美中國歐美中國算是體操大國歐美中國也投資很多資源在體操為什麼在台灣培訓被台灣教練訓練李智凱能夠在奧運體操鞍馬項目勝過歐美中國'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '李智凱敢挑戰街健嗎街健肌肉應用最高形式完美控制身體藝術相比之下體操簡直是平淡創意卻企圖以華麗表演來掩飾李智凱雖然拿到奧運銀牌了但是不是還是不敢挑戰街健有沒有卦'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 5.2093,
#     'Anticipation': 0.0977,
#     'Disgust': 5.5036,
#     'Fear': 5.718,
#     'Joy': 0.7348,
#     'Sadness': 5.8055,
#     'Surprise': 0.1838,
#     'Trust': 0.7988,
#     'input_str': '李智凱沒拍過武打片李智凱好像是上屆奧運就很有名選手他顏值和身手尤其是掃堂腿應該很適合拍武打功夫片吧怎麼沒成為男主'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 7.613,
#     'Anticipation': 0.4363,
#     'Disgust': 8.1667,
#     'Fear': 7.9398,
#     'Joy': 0.7051,
#     'Sadness': 7.5377,
#     'Surprise': 1.3637,
#     'Trust': 1.9442,
#     'input_str': '中國體操鞍馬培養不出台灣李智凱等級選手最近覺青真蠻好笑中國拿銀作圖嘲笑中國拿銀牌洗版整天中國拿金金牌數第一關我屁事他國事務這種鴕鳥式愛台看到都覺得羞愧'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '中國體操鞍馬培養不出台灣李智凱等級選手引述綠營重新執政之銘言中國不是算體操大國嗎為什麼李智凱能大勝中國鞍馬參賽者李智凱拿鞍馬銀牌中國選手連銅牌都沒有為什麼中國體操鞍馬培養不出台灣李智凱等級選手雖然知道是反串但無聊還是來嗆一下年後老人阿公阿嬤'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '中國體操鞍馬培養不出台灣李智凱等級選手中國不是算體操大國嗎為什麼李智凱能大勝中國鞍馬參賽者李智凱拿鞍馬銀牌中國選手連銅牌都沒有為什麼中國體操鞍馬培養不出台灣李智凱等級選手'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.7458,
#     'Anticipation': 7.033,
#     'Disgust': 0.9264,
#     'Fear': 0.2766,
#     'Joy': 7.1949,
#     'Sadness': 1.4924,
#     'Surprise': 6.958,
#     'Trust': 6.2177,
#     'input_str': '李智凱完美落地摘銀謝長廷謝謝他實現他不是第一次提到奧運是他夢想這件事了而是三不五時遇到選手就會把這件事情拿出來說一下對奧運真很執著最早從年爭取舉辦奧運開始就有提到謝長廷台灣應爭取主辦年奧運年遇到日本奧運選手也提過新聞也有報導謝長廷會見日本冰'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8353,
#     'Anticipation': 6.877,
#     'Disgust': 0.207,
#     'Fear': 0.184,
#     'Joy': 7.1551,
#     'Sadness': 0.9358,
#     'Surprise': 7.7031,
#     'Trust': 5.6855,
#     'input_str': '李智凱完美落地摘銀彭于晏第一時間引述楓糖蛋糕之銘言李智凱完美落地摘銀彭于晏第一時間傳訊字祝賀娛樂中心詹鎰睿報導我國台灣體操好手李智凱今日成功在東京奧運鞍馬項目奪下銀牌讓台灣全體人民紛紛祝賀慶祝對此曾在電影翻滾吧阿信飾演李智凱教練'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.8353,
#     'Anticipation': 6.877,
#     'Disgust': 0.207,
#     'Fear': 0.184,
#     'Joy': 7.1551,
#     'Sadness': 0.9358,
#     'Surprise': 7.7031,
#     'Trust': 5.6855,
#     'input_str': '李智凱完美落地摘銀彭于晏第一時間李智凱完美落地摘銀彭于晏第一時間傳訊字祝賀娛樂中心詹鎰睿報導我國台灣體操好手李智凱今日成功在東京奧運鞍馬項目奪下銀牌讓台灣全體人民紛紛祝賀慶祝對此曾在電影翻滾吧阿信飾演李智凱教練林育信男星彭于晏'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '李智凱完美落地摘銀謝長廷謝謝他實現這篇噓人真不知道是噓什麼小朋友謝長廷真在中學時期是練體操身為體操選手謝有參加過中上運動會全中運前身及省運會全運會前身前者拿下金牌後者銅牌吊環水準在當時有全國前三實力這些資料上都查到作為一個傑出體操選'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 5.9026,
#     'Anticipation': 0.0671,
#     'Disgust': 6.0153,
#     'Fear': 5.8818,
#     'Joy': 0.36,
#     'Sadness': 5.7502,
#     'Surprise': 0.3641,
#     'Trust': 0.0974,
#     'input_str': '李智凱國中都有交功課各位八卦版廢宅午安事情是這樣啦本帥帥剛剛看新聞看到新聞在訪問鞍馬王子李智凱國中老師他老師說他國中很乖事情都很肯做也不會因為自己練體操就不交作業這時我想到我當年國中時一堆廢物同學放學後都去打咖也都沒有寫作業人家李智凱體育班還'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.5355,
#     'Anticipation': 7.0361,
#     'Disgust': 0.7986,
#     'Fear': 0.2141,
#     'Joy': 7.4222,
#     'Sadness': 1.1834,
#     'Surprise': 6.9438,
#     'Trust': 6.6686,
#     'input_str': '李智凱完美落地摘銀謝長廷謝謝他實現東森新聞雲杜冠霖李智凱完美落地摘銀謝長廷謝謝他實現了我夢完整新聞內文在東京奧運體操鞍馬項目決賽中鞍馬王子李智凱使出高難度湯瑪士迴旋最後完美落地以總分分奪得銀牌也成為台灣史上首位拿下體操獎牌人對'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.5588,
#     'Anticipation': 6.3977,
#     'Disgust': 0.2864,
#     'Fear': 0.438,
#     'Joy': 6.7001,
#     'Sadness': 1.3001,
#     'Surprise': 6.7978,
#     'Trust': 5.9342,
#     'input_str': '李智凱苦練體操年你苦練了什麼引述火箭少女之銘言從翻滾吧男孩歲開始李智凱苦練體操年專精鞍馬項目幾乎年來天天跟鞍馬生活在一起到現在成為翻滾吧男人歲終於奧運奪銀你為了什麼也能夠苦練年呢有些事情不用為了出人頭地或是得獎才有動力一直苦練我認為最重要是心'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 1.4759,
#     'Anticipation': 7.0195,
#     'Disgust': 0.0958,
#     'Fear': 1.2037,
#     'Joy': 6.9031,
#     'Sadness': 1.6258,
#     'Surprise': 6.8162,
#     'Trust': 5.86,
#     'input_str': '李智凱苦練體操年你苦練了什麼從翻滾吧男孩歲開始李智凱苦練體操年專精鞍馬項目幾乎年來天天跟鞍馬生活在一起到現在成為翻滾吧男人歲終於奧運奪銀你為了什麼也能夠苦練年呢'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.6867,
#     'Anticipation': 5.918,
#     'Disgust': 0.9786,
#     'Fear': 0.7943,
#     'Joy': 7.4232,
#     'Sadness': 1.2547,
#     'Surprise': 7.5892,
#     'Trust': 5.3925,
#     'input_str': '小戴李智凱對羽球鞍馬貢獻都是開創性吧如題覺得今天兩個奧運銀牌某方面處境有點類似戴資穎和李智凱對羽球和鞍馬分別貢獻從整個運動發展角度來看應該都是開創性歷史性同樣都大大增加了運動觀賞性有趣性開創出新玩法和領域但是也同樣要面臨在爭取'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Success!',
#   'results': [{'Anger': 0.0,
#     'Anticipation': 0.0,
#     'Disgust': 0.0,
#     'Fear': 0.0,
#     'Joy': 0.0,
#     'Sadness': 0.0,
#     'Surprise': 0.0,
#     'Trust': 0.0,
#     'input_str': '智智老公指的是李智凱嗎引述張阿月紅茶冰之銘言智智老公醬汁量普通大約有是濃稠米黃色像美乃滋一樣甜度很高有河流楓糖鳶尾草味道非常濃甜吃起來卻一點都不膩就像完美配合精心製作煉乳就像智智老公一樣聰明溫柔總是能給人暖暖驚喜這邊說智智老公指是'}],
#   'sense': 'sense8',
#   'status': True,
#   'version': 'v102'},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38},
#  {'msg': 'Insufficient word count balance.',
#   'status': False,
#   'word_count_balance': 38}]

# %%
KeyMoji_score[18]['results']
# Out:
# [{'Anger': 0.0,
#   'Anticipation': 0.0,
#   'Disgust': 0.0,
#   'Fear': 0.0,
#   'Joy': 0.0,
#   'Sadness': 0.0,
#   'Surprise': 0.0,
#   'Trust': 0.0,
#   'input_str': '智智老公指的是李智凱嗎引述張阿月紅茶冰之銘言智智老公醬汁量普通大約有是濃稠米黃色像美乃滋一樣甜度很高有河流楓糖鳶尾草味道非常濃甜吃起來卻一點都不膩就像完美配合精心製作煉乳就像智智老公一樣聰明溫柔總是能給人暖暖驚喜這邊說智智老公指是'}]

# %%
x = []
KeyMoji_result = []
for i in range(0,18):
  x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
          KeyMoji_score[i]['results'][0]['Anger'],
          KeyMoji_score[i]['results'][0]['Anticipation'],
          KeyMoji_score[i]['results'][0]['Disgust'],
          KeyMoji_score[i]['results'][0]['Fear'],
          KeyMoji_score[i]['results'][0]['Joy'],
          KeyMoji_score[i]['results'][0]['Sadness'],
          KeyMoji_score[i]['results'][0]['Surprise'],
          KeyMoji_score[i]['results'][0]['Trust']])
  KeyMoji_result.append(x)

# %%
LEE_KeyMoji_score = pd.DataFrame(KeyMoji_result)
LEE_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_ALL_LEE.csv"

path = save_path_Keymoji + name
store_to_csv_df(LEE_KeyMoji_score, path)

# %%
# # check
# KeyMoji_score[0]['results'][0]
# Out:
# {'Anger': 2.4902,
#  'Anticipation': 0.5397,
#  'Disgust': 12.5,
#  'Fear': 0.5853,
#  'Joy': 0.5593,
#  'Sadness': 2.3929,
#  'Surprise': 0.5058,
#  'Trust': 0.5238,
#  'input_str': '問卦歐美中國舉重同量級無法超越台灣郭婞淳'}

# %%
# len(KeyMoji_score[0]['results'][0])

# %%
def My_KeyMoji(data):
  # 若您是使用 Docker 版本，無須填入 username, keymoji_key 參數
  keymoji = KeyMoji(username="", keymojiKey="")

  KeyMoji_score = []
  for i in range(len(data)):
    KeyMoji_score.append(keymoji.sense8(data[0][i]))
  print(KeyMoji_score)
  
  x = []
  for i in range(len(KeyMoji_score)):
    x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
            KeyMoji_score[i]['results'][0]['Anger'],
            KeyMoji_score[i]['results'][0]['Anticipation'],
            KeyMoji_score[i]['results'][0]['Disgust'],
            KeyMoji_score[i]['results'][0]['Fear'],
            KeyMoji_score[i]['results'][0]['Joy'],
            KeyMoji_score[i]['results'][0]['Sadness'],
            KeyMoji_score[i]['results'][0]['Surprise'],
            KeyMoji_score[i]['results'][0]['Trust']])
    KeyMoji_result.append(x)

# %%
# LEE
KeyMoji_result = []
My_KeyMoji(LEE_title_df)
LEE_KeyMoji_score = pd.DataFrame(KeyMoji_result)
LEE_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_ALL_LEE.csv"

path = save_path_Keymoji + name
store_to_csv_df(LEE_KeyMoji_score, path)
# Out:
# [{'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}, {'status': False, 'msg': 'Insufficient word count balance.', 'word_count_balance': 15}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-f928fe8e01b4> in <module>()
#       1 # LEE
#       2 KeyMoji_result = []
# ----> 3 My_KeyMoji(LEE_title_df)
#       4 LEE_KeyMoji_score = pd.DataFrame(KeyMoji_result)
#       5 LEE_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
#
# <ipython-input-30-d36962a8bf91> in My_KeyMoji(data)
#      10   x = []
#      11   for i in range(len(KeyMoji_score)):
# ---> 12     x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
#      13             KeyMoji_score[i]['results'][0]['Anger'],
#      14             KeyMoji_score[i]['results'][0]['Anticipation'],
#
# KeyError: 'results'

# %%
# GUO
KeyMoji_result = []
My_KeyMoji(GUO_title_df)
GUO_KeyMoji_score = pd.DataFrame(KeyMoji_result)
GUO_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_ALL_GUO.csv"

path = save_path_Keymoji + name
store_to_csv_df(GUO_KeyMoji_score, path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-72a19fb04026> in <module>()
#       1 # GUO
#       2 KeyMoji_result = []
# ----> 3 My_KeyMoji(GUO_title_df)
#       4 GUO_KeyMoji_score = pd.DataFrame(KeyMoji_result)
#       5 GUO_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
#
# <ipython-input-17-4a8e3d9b529f> in My_KeyMoji(data)
#      10   x = []
#      11   for i in range(len(KeyMoji_score)):
# ---> 12     x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
#      13             KeyMoji_score[i]['results'][0]['Anger'],
#      14             KeyMoji_score[i]['results'][0]['Anticipation'],
#
# KeyError: 'results'

# %%
# YANG
KeyMoji_result = []
My_KeyMoji(YANG_title_df)
YANG_KeyMoji_score = pd.DataFrame(KeyMoji_result)
YANG_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_ALL_YANG.csv"

path = save_path_Keymoji + name
store_to_csv_df(YANG_KeyMoji_score, path)

# %%
# TAI
KeyMoji_result = []
My_KeyMoji(TAI_title_df)
TAI_KeyMoji_score = pd.DataFrame(KeyMoji_result)
TAI_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_ALL_TAI.csv"

path = save_path_Keymoji + name
store_to_csv_df(TAI_KeyMoji_score, path)

# %%
# LIN
KeyMoji_result = []
My_KeyMoji(LIN_title_df)
LIN_KeyMoji_score = pd.DataFrame(KeyMoji_result)
LIN_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_ALL_LIN.csv"

path = save_path_Keymoji + name
store_to_csv_df(LIN_KeyMoji_score, path)

# %%
# LEE_KeyMoji_score = pd.DataFrame(LEE_KeyMoji_score)
x = []
KeyMoji_result = []
for i in range(len(KeyMoji_score)):
  x = np.array([KeyMoji_score[i]['results'][0]['input_str'],
          KeyMoji_score[i]['results'][0]['Anger'],
          KeyMoji_score[i]['results'][0]['Anticipation'],
          KeyMoji_score[i]['results'][0]['Disgust'],
          KeyMoji_score[i]['results'][0]['Fear'],
          KeyMoji_score[i]['results'][0]['Joy'],
          KeyMoji_score[i]['results'][0]['Sadness'],
          KeyMoji_score[i]['results'][0]['Surprise'],
          KeyMoji_score[i]['results'][0]['Trust']])
  KeyMoji_result.append(x)

YANG_KeyMoji_score = pd.DataFrame(KeyMoji_result)
YANG_KeyMoji_score.columns = ['Title', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
name = "KeyMoji_score_YANG.csv"

path = save_path + name
store_to_csv_df(YANG_KeyMoji_score, path)

# %%
# LEE_KeyMoji_score.columns = ['article','Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']
# LEE_KeyMoji_score

# %%
# name = "KeyMoji_score_LEE.csv"

# path = save_path + name
# store_to_csv_df(LEE_KeyMoji_score, path)

# %%
print(result)

keymoji.keymoji2visual(result)

# %%
result = keymoji.tension(text)
print(result)

# %%
keymoji.keymoji2visual(result)
